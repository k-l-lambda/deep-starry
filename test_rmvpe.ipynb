# %%
import os
import librosa
import matplotlib.pyplot as plt

from starry.rmvpe.inference import RMVPE


pe = RMVPE(os.path.expanduser('~/Downloads/rmvpe/model.pt'))
sample, _ = librosa.load('./test/vocals-clip3.wav', sr=16000)
f0, uv = pe.get_pitch(sample, sample.shape[0] // 512, dict(audio_sample_rate=16000, hop_size=512), interp_uv=True)
plt.plot(f0)

# %%
import torch
import matplotlib.pyplot as plt


data = torch.load('test/audio/abjones_1_03.pitch.pt')
plt.plot(data['f0'])
