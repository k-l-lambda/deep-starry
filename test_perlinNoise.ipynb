# %%
from perlin_noise import PerlinNoise
import matplotlib.pyplot as plt


noise = PerlinNoise(octaves=2)

plt.plot([noise(x / 1000) for x in range(1000)])
plt.show()

# %%
import matplotlib.pyplot as plt

import starry.utils.env
from starry.utils.perlin1d import Perlin1d


perlin = Perlin1d()

plt.plot(perlin.get(800, 240))
plt.show()
# Out:
# cache: 6 256 1024

# %%
import matplotlib.pyplot as plt

import starry.utils.env
from starry.utils.perlin1d import Perlin1d


perlin = Perlin1d()

plt.plot(perlin.integralLinear(400, 240))
plt.show()

# %%
import matplotlib.pyplot as plt

import starry.utils.env
from starry.utils.perlin1d import Perlin1d


perlin = Perlin1d()

plt.gca().set_aspect(1)
plt.plot(perlin.integralExp(800, 240, amplitude=4))
plt.show()
