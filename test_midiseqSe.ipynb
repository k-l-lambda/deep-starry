# %%
import os

from starry.utils.config import Configuration
from starry.utils.dataset_factory import loadDataset
from starry.utils.model_factory import loadModel


DATA_DIR = os.getenv('DATA_DIR')

config = Configuration.create('configs/midiseq-paraff-se.yaml', volatile=True)
train, val = loadDataset(config, data_dir=DATA_DIR, device='cpu')
model = loadModel(config['model'], postfix='Loss')

it = iter(train)

batch = next(it)
loss, metric = model(batch)

loss, metric
# Out:
# (tensor(1.0272, grad_fn=<AddBackward0>),
#  {'cos_angle': 0.02127060294151306,
#   'angle': 1.549511432647705,
#   'encode_loss': 0.6726706027984619,
#   'decode_loss': 5.909289360046387,
#   'acc': 0.0})

# %%
import torch


with torch.autograd.set_detect_anomaly(True):
	loss.backward()
