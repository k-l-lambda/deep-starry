# %%
import os

import starry.utils.env
from starry.paraff.data.paraffFile import ParaffFile


DATA_DIR = os.environ.get('DATA_DIR')

file = ParaffFile(open(os.path.join(DATA_DIR, '20230301.paraff'), 'rb'))
print(file.tokens)

file.sentences[0]
# Out:
# ['PAD', 'BOS', 'EOS', 'VB', 'S1', 'S2', 'S3', 'Cg', 'Cf', 'Cc', 'K0', 'K1', 'K2', 'K3', 'K4', 'K5', 'K6', 'K_1', 'K_2', 'K_3', 'K_4', 'K_5', 'K_6', 'TN1', 'TN2', 'TN3', 'TN4', 'TN5', 'TN6', 'TN7', 'TN8', 'TN9', 'TN10', 'TN11', 'TN12', 'TD2', 'TD4', 'TD8', 'a', 'b', 'c', 'd', 'e', 'f', 'g', 'As', 'Af', 'Ass', 'Aff', 'Osup', 'Osub', 'O0', 'Ova', 'Ovb', 'D1', 'D2', 'D4', 'D8', 'D16', 'D32', 'D64', 'D128', 'D256', 'Dot', 'Bl', 'Br', 'Mu', 'Md', 'Rest', 'W2', 'W3', 'W4', 'W5', 'W6', 'W7', 'W8', 'W9', 'W10', 'Wx', 'W', 'G']
# [1,
#  14,
#  26,
#  36,
#  4,
#  7,
#  39,
#  49,
#  55,
#  68,
#  39,
#  56,
#  68,
#  66,
#  39,
#  56,
#  3,
#  5,
#  7,
#  66,
#  39,
#  42,
#  44,
#  45,
#  57,
#  64,
#  39,
#  42,
#  44,
#  45,
#  57,
#  39,
#  42,
#  44,
#  45,
#  57,
#  41,
#  45,
#  44,
#  45,
#  57,
#  65,
#  41,
#  45,
#  44,
#  45,
#  57,
#  64,
#  39,
#  42,
#  44,
#  45,
#  57,
#  39,
#  42,
#  44,
#  45,
#  57,
#  39,
#  42,
#  44,
#  45,
#  57,
#  65,
#  3,
#  6,
#  8,
#  66,
#  42,
# ...
