# %%
from jinja2 import Environment, FileSystemLoader

env = Environment(loader=FileSystemLoader('../assets'))

template = env.get_template('paraffUndPrompt.jinja')

template
# Out:
# <Template 'paraffUndPrompt.jinja'>

# %%
import random


template.render(i1=0, i2=0, i3=0, i4=0).strip()
# Out:
# 'recognize this image as paraff'
